# %% [markdown]
# # RECON evaporation shed
#
# Script to retrieve and plot the reconciled moisture flow of evaporation at the source falling as rainfall
# in downwind locations based on NetCDF moisture flow data (RECON).
#
# This notebook presents an example usage with specific latitude and longitude values of the source (location of evaporation).
# You can set a location of evaporation (`lon` and `lat` variables) and get its evaporation shed, i.e., the precipitation flows in downind cells (target) contributing to its annual evaporation.
#
# Created by Elena De Petrillo (elena.depetrillo@polito.it) & Luca Monaco (luca.monaco@cimafoundation.org)
# Modified by Romain Thomas (contact@romainthomas.net)
#
# 2025

# %% [markdown]
# ## Imports

# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap

# %% [markdown]
# ## Variables

# %%
# Set the path where the dataset is stored
input_file = "RECON_moisture_flows_0.5.nc"
# Set the path where you want to save the plot
output_map_plot_path = "evaporation_shed_map.png"

# Constants for calculation
ymax = 122079329.40990189  # Maximum moisture flow value
ymin = 10**-3  # Minimum moisture flow value

# Modify these coordinates to analyze different points
# Turin
lon = 7.7 # from 0 to 360
lat = 45.1 # from 90 to -90
# # Brazil
# lat = -8
# lon = 311

# %% [markdown]
# ## Data processing

# %% [markdown]
# ### Load dataset

# %%
dataset = xr.open_dataset(input_file)

# %% [markdown]
# ### Get the evaporation shed
#
# It needs to be converted in cubic meters

# %%
evaporation_shed_raw = dataset["moisture_flow"].sel(sourcelat=lat, sourcelon=lon,method="nearest").values

# %% [markdown]
# ### Convert to cubic meters

# %%
evaporation_shed = np.where(
    evaporation_shed_raw== 0,
    0,
    10**(((evaporation_shed_raw- 1) / 254) * (np.log10(ymax) - np.log10(ymin)) + np.log10(ymin))
)

# %% [markdown]
# ## Plot results

# %%
lats = np.arange(90, -90, -0.5)
lons = np.arange(-180, 180, 0.5)

# Shift the data east by 180°
shift_degrees = 180
shift_pixels = int(shift_degrees / (360.0 / evaporation_shed.shape[1]))
shifted_shed = np.roll(evaporation_shed, shift=shift_pixels, axis=1)

plt.figure(figsize=(12, 5))

# Mask zero values in the shifted shed data
masked_shed = np.ma.masked_where(shifted_shed == 0, shifted_shed)
cmap = plt.get_cmap('Reds')
cmap.set_bad(color='white')  # Set masked (zero) values to white

# Create the Basemap, centered at 0°
m = Basemap(
    projection='cyl',
    llcrnrlat=-90, urcrnrlat=90,
    llcrnrlon=-180, urcrnrlon=180,
    resolution='c',
)

# Create lon/lat grids and project them
lon2d, lat2d = np.meshgrid(lons, lats)
x, y = m(lon2d, lat2d)

# Plot the shifted data in map coordinates
cs = m.pcolormesh(x, y, masked_shed, cmap=cmap, shading='auto', vmin=0)

# Add borders, coastlines, grid
m.drawcoastlines()
m.drawcountries()
m.drawparallels(np.arange(-90, 91, 30), labels=[1,0,0,0])
m.drawmeridians(np.arange(0, 361, 60), labels=[0,0,0,1])

# Plot the point in map coordinates
x_pt, y_pt = m((lon + shift_degrees) % 360 - shift_degrees, lat)
m.plot(x_pt, y_pt, 'go', markersize=3, markeredgewidth=0)

def decimal_to_dms(decimal, is_latitude=False):
    if is_latitude:
        direction = "N" if decimal >= 0 else "S"
    else:
        direction = "E" if decimal >= 0 else "W"
    degrees = abs(decimal)
    return f"{degrees}° {direction}"

plt.colorbar(cs, label="moisture flow [m$^3$]")
plt.title(f"Annual precipiration contributing to evaporation at location (Lat: {decimal_to_dms(lat, True)}, Lon: {decimal_to_dms(lon)})")
plt.xlabel("Longitude", labelpad=20)
plt.ylabel("Latitude", labelpad=20)

plt.tight_layout()
plt.savefig(output_map_plot_path, dpi=200, bbox_inches='tight')
print(f"Plot saved at {output_map_plot_path}")
plt.show()
# Out:
# Plot saved at evaporation_shed_map.png
